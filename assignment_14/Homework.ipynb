# %% [markdown]
# # HOMEWORK 13
#
# In this homework you are going to build your first classifier for the CIFAR-10 dataset. This dataset contains 10 different classes and you can learn more about it [here](https://www.cs.toronto.edu/~kriz/cifar.html). This homework consists of the following tasks:
# * Dataset inspection
# * Building the network
# * Training
# * Evaluation
#
# At the end, as usual, there will be a couple of questions for you to answer :-)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Input, MaxPooling2D
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# %% [markdown]
# ### Step 0: Dataset Inspection
#
# Load the dataset and make a quick inspection.

# %%
# Load the dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Mapping from class ID to class name
classes = {0:'plane', 1:'car', 2:'bird', 3:'cat', 4:'deer',
           5:'dog', 6:'frog', 7:'horse', 8:'ship', 9:'truck'}

# Dataset params
num_classes = len(classes)
size = x_train.shape[1]

# Visualize random samples (as a plot with 3x6 samples)
for ii in range(18):    
    plt.subplot(3,6,ii+1)
    # Pick a random sample
    idx = np.random.randint(0, num_classes)
    # Show the image and the label
    plt.imshow(x_train[idx, ...])
    plt.title(classes[int(y_train[idx])])
# Out:
# /var/folders/wk/bcl8sq5n79l774hgn1lclt9r0000gn/T/ipykernel_93717/1472696751.py:18: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.title(classes[int(y_train[idx])])

# %% [markdown]
# Compute the class histogram (you can visualize it if you want). Is the dataset balanced?
#
# Hint: You might find [Counter](https://docs.python.org/3/library/collections.html#collections.Counter) tool useful. In any case, it's up to you how you compute the histogram.

# %%
# Compute the class histogram
from collections import Counter

hist = Counter(y_train.flatten())

plt.bar(hist.keys(), hist.values()), plt.grid(True)
plt.xlabel('Class ID'), plt.ylabel('Counts')
# Out:
# (Text(0.5, 0, 'Class ID'), Text(0, 0.5, 'Counts'))

# %% [markdown]
# ### Step 1: Data Preparation
#
# In this step, you'll need to prepare the data for training, i.e., you will have to normalize it and encode the labels as one-hot vectors.

# %%
# Normalization
x_train = x_train/255
x_test = x_test/255

# One-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Train set:    50000 samples
# Test set:     10000 samples
# Sample dims:  (50000, 32, 32, 3)

# %% [markdown]
# ### Step 2: Building the Classifier
#
# Build the CNN for CIFAR10 classification. For starters, you can use the same network we used in the lesson for the MNIST problem.

# %%
# Build the classifier
inputs = Input(shape=(size, size, 3))

net = Conv2D(16, kernel_size=(3, 3), activation="relu")(inputs)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Conv2D(32, kernel_size=(3, 3), activation="relu")(net)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Flatten()(net)
outputs = Dense(num_classes, activation="softmax")(net)

model = Model(inputs, outputs)

# Show the model
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 30, 30, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 15, 15, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 13, 13, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 6, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │        11,530 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,618 (64.91 KB)
#  Trainable params: 16,618 (64.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Step 3: Training
#
# Compile the model and train it.

# %%
print(x_train.shape)
# Out:
# (50000, 32, 32, 3)

# %%
epochs = 25
batch_size = 128

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/25
# 2025-05-11 16:35:12.931192: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.3031 - loss: 1.9427 - val_accuracy: 0.4642 - val_loss: 1.5303
# Epoch 2/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.4860 - loss: 1.4606 - val_accuracy: 0.5050 - val_loss: 1.3972
# Epoch 3/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.5373 - loss: 1.3287 - val_accuracy: 0.5478 - val_loss: 1.2842
# Epoch 4/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.5673 - loss: 1.2487 - val_accuracy: 0.5842 - val_loss: 1.2000
# Epoch 5/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.5888 - loss: 1.1887 - val_accuracy: 0.6050 - val_loss: 1.1467
# Epoch 6/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6051 - loss: 1.1425 - val_accuracy: 0.6206 - val_loss: 1.1128
# Epoch 7/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6203 - loss: 1.1063 - val_accuracy: 0.6248 - val_loss: 1.0889
# Epoch 8/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.6307 - loss: 1.0768 - val_accuracy: 0.6318 - val_loss: 1.0690
# Epoch 9/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.6398 - loss: 1.0522 - val_accuracy: 0.6402 - val_loss: 1.0533
# Epoch 10/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.6476 - loss: 1.0314 - val_accuracy: 0.6408 - val_loss: 1.0408
# Epoch 11/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6535 - loss: 1.0136 - val_accuracy: 0.6438 - val_loss: 1.0309
# Epoch 12/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.6590 - loss: 0.9978 - val_accuracy: 0.6450 - val_loss: 1.0233
# Epoch 13/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6627 - loss: 0.9825 - val_accuracy: 0.6480 - val_loss: 1.0120
# Epoch 14/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6695 - loss: 0.9680 - val_accuracy: 0.6514 - val_loss: 1.0047
# Epoch 15/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6736 - loss: 0.9550 - val_accuracy: 0.6532 - val_loss: 0.9999
# Epoch 16/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6765 - loss: 0.9436 - val_accuracy: 0.6536 - val_loss: 0.9938
# Epoch 17/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6803 - loss: 0.9329 - val_accuracy: 0.6574 - val_loss: 0.9893
# Epoch 18/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6834 - loss: 0.9229 - val_accuracy: 0.6598 - val_loss: 0.9856
# Epoch 19/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6864 - loss: 0.9136 - val_accuracy: 0.6614 - val_loss: 0.9806
# Epoch 20/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6889 - loss: 0.9047 - val_accuracy: 0.6622 - val_loss: 0.9767
# Epoch 21/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6908 - loss: 0.8964 - val_accuracy: 0.6634 - val_loss: 0.9742
# Epoch 22/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6938 - loss: 0.8885 - val_accuracy: 0.6648 - val_loss: 0.9702
# Epoch 23/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6968 - loss: 0.8807 - val_accuracy: 0.6640 - val_loss: 0.9675
# Epoch 24/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6992 - loss: 0.8735 - val_accuracy: 0.6668 - val_loss: 0.9652
# Epoch 25/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.7017 - loss: 0.8664 - val_accuracy: 0.6676 - val_loss: 0.9624

# %%
# Show training history (this cell is complete, nothing to implement here :-) )
h = history.history
epochs = range(len(h['loss']))

plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
plt.legend(['Train', 'Validation'])
plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                           epochs, h['val_accuracy'], '.-')
plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

print('Train Acc     ', h['accuracy'][-1])
print('Validation Acc', h['val_accuracy'][-1])
# Out:
# Train Acc      0.7040444612503052
# Validation Acc 0.6675999760627747

# %% [markdown]
# ### Step 4: Evaluation
#
# In this step, you have to calculate the accuracies and visualize some random samples. For the evaluation, you are going to use the test split from the dataset.

# %%
# Compute the labels and the predictions as sparse values
y_true = np.argmax(y_test, axis=1)
y_pred = np.argmax(model.predict(x_test), axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# Compute and print the accuracy for each class
for class_id, class_name in classes.items():
    idxs = np.where(y_true == class_id)[0]
    acc = np.mean(y_pred[idxs] == y_true[idxs])
    print(class_name, acc)
# Out:
# plane 0.701
# car 0.797
# bird 0.575
# cat 0.409
# deer 0.679
# dog 0.642
# frog 0.73
# horse 0.671
# ship 0.712
# truck 0.757

# %%
# Print the overall stats
ev = model.evaluate(x_test, y_test)
print('Test loss  ', ev[0])
print('Test metric', ev[1])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6684 - loss: 0.9736
# Test loss   0.9814269542694092
# Test metric 0.6672999858856201

# %%
# Show random samples
for ii in range(15):
    # Pick a random sample
    idx = np.random.randint(0, len(x_test))
    # Show the results
    plt.subplot(3,5,ii+1), plt.imshow(x_test[idx, ...])
    plt.title('True: ' + str(classes[y_true[idx]]) + ' | Pred: ' + str(classes[y_pred[idx]]))

# %% [markdown]
# ### Questions
# * What is the overall accuracy of the classifier?
# * What modifications would you do in order to improve the classification accuracy?
# * Make **one** modification (that you think can help) and train the classifier again. Does the accuracy improve?
#
#
# 1. У меня получилась общая точность 0.6672999858856201.
# 2. Для улучшения точности можно попробывть изменить количество фильтров, увеличить количество слоев или нейронов в слое Dense.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Normalization
x_train = x_train/255
x_test = x_test/255

# One-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# Build the classifier
inputs = Input(shape=(size, size, 3))

net = Conv2D(32, kernel_size=(3, 3), activation="relu")(inputs)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Conv2D(64, kernel_size=(3, 3), activation="relu")(net)
net = MaxPooling2D(pool_size=(2, 2))(net)
net = Flatten()(net)
outputs = Dense(num_classes, activation="softmax")(net)

model = Model(inputs, outputs)

# Show the model
model.summary()

epochs = 25
batch_size = 128

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)


# Show training history (this cell is complete, nothing to implement here :-) )
h = history.history
epochs = range(len(h['loss']))

plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
plt.legend(['Train', 'Validation'])
plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                           epochs, h['val_accuracy'], '.-')
plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

print('Train Acc     ', h['accuracy'][-1])
print('Validation Acc', h['val_accuracy'][-1])    

# Print the overall stats
ev = model.evaluate(x_test, y_test)
print('Test loss  ', ev[0])
print('Test metric', ev[1])
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_13 (InputLayer)     │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_23 (MaxPooling2D) │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_11 (Flatten)            │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 10)             │        23,050 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 42,442 (165.79 KB)
#  Trainable params: 42,442 (165.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.3264 - loss: 1.8700 - val_accuracy: 0.4910 - val_loss: 1.4671
# Epoch 2/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.5239 - loss: 1.3670 - val_accuracy: 0.5452 - val_loss: 1.3219
# Epoch 3/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.5741 - loss: 1.2310 - val_accuracy: 0.6024 - val_loss: 1.1661
# Epoch 4/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6074 - loss: 1.1347 - val_accuracy: 0.6304 - val_loss: 1.0860
# Epoch 5/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6339 - loss: 1.0659 - val_accuracy: 0.6488 - val_loss: 1.0438
# Epoch 6/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.6541 - loss: 1.0137 - val_accuracy: 0.6512 - val_loss: 1.0172
# Epoch 7/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6695 - loss: 0.9724 - val_accuracy: 0.6606 - val_loss: 0.9961
# Epoch 8/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6829 - loss: 0.9378 - val_accuracy: 0.6654 - val_loss: 0.9780
# Epoch 9/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6918 - loss: 0.9084 - val_accuracy: 0.6684 - val_loss: 0.9636
# Epoch 10/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7001 - loss: 0.8812 - val_accuracy: 0.6716 - val_loss: 0.9539
# Epoch 11/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7089 - loss: 0.8572 - val_accuracy: 0.6760 - val_loss: 0.9441
# Epoch 12/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7163 - loss: 0.8347 - val_accuracy: 0.6786 - val_loss: 0.9367
# Epoch 13/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7224 - loss: 0.8144 - val_accuracy: 0.6816 - val_loss: 0.9313
# Epoch 14/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7295 - loss: 0.7953 - val_accuracy: 0.6856 - val_loss: 0.9250
# Epoch 15/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7356 - loss: 0.7780 - val_accuracy: 0.6890 - val_loss: 0.9221
# Epoch 16/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7412 - loss: 0.7620 - val_accuracy: 0.6892 - val_loss: 0.9203
# Epoch 17/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7460 - loss: 0.7466 - val_accuracy: 0.6884 - val_loss: 0.9229
# Epoch 18/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7508 - loss: 0.7326 - val_accuracy: 0.6878 - val_loss: 0.9227
# Epoch 19/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7567 - loss: 0.7195 - val_accuracy: 0.6906 - val_loss: 0.9235
# Epoch 20/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7616 - loss: 0.7064 - val_accuracy: 0.6926 - val_loss: 0.9248
# Epoch 21/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7664 - loss: 0.6942 - val_accuracy: 0.6914 - val_loss: 0.9245
# Epoch 22/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7694 - loss: 0.6830 - val_accuracy: 0.6918 - val_loss: 0.9260
# Epoch 23/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7737 - loss: 0.6724 - val_accuracy: 0.6888 - val_loss: 0.9306
# Epoch 24/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7767 - loss: 0.6633 - val_accuracy: 0.6888 - val_loss: 0.9346
# Epoch 25/25
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7807 - loss: 0.6537 - val_accuracy: 0.6902 - val_loss: 0.9375
# Train Acc      0.7817333340644836
# Validation Acc 0.6901999711990356
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6896 - loss: 0.9725
# Test loss   0.9764189720153809
# Test metric 0.6819000244140625

# %% [markdown]
# Увеличил в два раза количество ядер в слоях свертки. Общая точность увеличилась с 0,6672 до 0,6819. Незначительно но увеличилась.
